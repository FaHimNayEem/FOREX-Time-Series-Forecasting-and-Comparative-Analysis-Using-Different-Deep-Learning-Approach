# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

# %%
# !cp /content/drive/MyDrive/thesis.py /content

# %%
import thesis
#def IMPORT():
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

# %%
df = pd.read_csv('/content/drive/MyDrive/Thesis Dataset/JPY_USD_5min.csv')
df.dropna(inplace=True)
df['timestamp'] = pd.to_datetime(df['timestamp'], infer_datetime_format=True)

df.set_index('timestamp', inplace=True)
print(df.shape)
df.head()
# Out:
# (222740, 4)
#                         open    close      low     high
# timestamp
# 2020-01-01 17:00:00  108.730  108.751  108.715  108.751
# 2020-01-01 17:05:00  108.759  108.738  108.736  108.759
# 2020-01-01 17:10:00  108.738  108.728  108.590  108.750
# 2020-01-01 17:15:00  108.728  108.677  108.575  108.735
# 2020-01-01 17:20:00  108.679  108.686  108.679  108.694

# %%
df=thesis.AddingColumn(df)
print(df.shape)
df.head()
# Out:
# /content/thesis.py:42: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df['week'] = df.index.week
# (222739, 12)
#                         open    close      low     high  previous_close  hour  \
# timestamp
# 2020-01-01 17:00:00  108.730  108.751  108.715  108.751         108.738    17
# 2020-01-01 17:05:00  108.759  108.738  108.736  108.759         108.728    17
# 2020-01-01 17:10:00  108.738  108.728  108.590  108.750         108.677    17
# 2020-01-01 17:15:00  108.728  108.677  108.575  108.735         108.686    17
# 2020-01-01 17:20:00  108.679  108.686  108.679  108.694         108.703    17
#
#                      day  week  momentum  avg_price  range  ohlc_price
# timestamp
# 2020-01-01 17:00:00    2     1    -0.021   108.7330  0.036   108.73675
# 2020-01-01 17:05:00    2     1     0.021   108.7475  0.023   108.74800
# 2020-01-01 17:10:00    2     1     0.010   108.6700  0.160   108.70150
# 2020-01-01 17:15:00    2     1     0.051   108.6550  0.160   108.67875
# 2020-01-01 17:20:00    2     1    -0.007   108.6865  0.015   108.68450

# %%
df=thesis.ApplyPCA(df)
df.head()
# Out:
#                         open    close      low     high  previous_close  hour  \
# timestamp
# 2020-01-01 17:00:00  108.730  108.751  108.715  108.751         108.738    17
# 2020-01-01 17:05:00  108.759  108.738  108.736  108.759         108.728    17
# 2020-01-01 17:10:00  108.738  108.728  108.590  108.750         108.677    17
# 2020-01-01 17:15:00  108.728  108.677  108.575  108.735         108.686    17
# 2020-01-01 17:20:00  108.679  108.686  108.679  108.694         108.703    17
#
#                      day  week  momentum  avg_price  range  ohlc_price  \
# timestamp
# 2020-01-01 17:00:00    2     1    -0.021   108.7330  0.036   108.73675
# 2020-01-01 17:05:00    2     1     0.021   108.7475  0.023   108.74800
# 2020-01-01 17:10:00    2     1     0.010   108.6700  0.160   108.70150
# 2020-01-01 17:15:00    2     1     0.051   108.6550  0.160   108.67875
# 2020-01-01 17:20:00    2     1    -0.007   108.6865  0.015   108.68450
#
#                            pca
# timestamp
# 2020-01-01 17:00:00 -22.264275
# 2020-01-01 17:05:00 -22.239555
# 2020-01-01 17:10:00 -22.374552
# 2020-01-01 17:15:00 -22.419420
# 2020-01-01 17:20:00 -22.390566

# %%
X = df.drop('close', axis=1)
print(X.head())
y=pd.DataFrame(df['close'])
print(y.head())
# Out:
#                         open      low     high  previous_close  hour  day  \
# timestamp
# 2020-01-01 17:00:00  108.730  108.715  108.751         108.738    17    2
# 2020-01-01 17:05:00  108.759  108.736  108.759         108.728    17    2
# 2020-01-01 17:10:00  108.738  108.590  108.750         108.677    17    2
# 2020-01-01 17:15:00  108.728  108.575  108.735         108.686    17    2
# 2020-01-01 17:20:00  108.679  108.679  108.694         108.703    17    2
#
#                      week  momentum  avg_price  range  ohlc_price        pca
# timestamp
# 2020-01-01 17:00:00     1    -0.021   108.7330  0.036   108.73675 -22.264275
# 2020-01-01 17:05:00     1     0.021   108.7475  0.023   108.74800 -22.239555
# 2020-01-01 17:10:00     1     0.010   108.6700  0.160   108.70150 -22.374552
# 2020-01-01 17:15:00     1     0.051   108.6550  0.160   108.67875 -22.419420
# 2020-01-01 17:20:00     1    -0.007   108.6865  0.015   108.68450 -22.390566
#                        close
# timestamp
# 2020-01-01 17:00:00  108.751
# 2020-01-01 17:05:00  108.738
# 2020-01-01 17:10:00  108.728
# 2020-01-01 17:15:00  108.677
# 2020-01-01 17:20:00  108.686

# %%
x_train, y_train, x_val, y_val, x_test, y_test = thesis.Train_Val_Test_split_15Min(X,y)
# Out:
# 178191
# 178191
# 7500
# 7500
# 37048
# 37048

# %%
x_train = x_train.values.astype('float32')
x_train=thesis.NormalizeDataset(x_train)

y_train = y_train.values.astype('float32')
y_train = np.reshape(y_train, (-1, 1))
y_train=thesis.NormalizeDataset(y_train)

x_train.shape
# Out:
# (178191, 12)

# %%
x_val = x_val.values.astype('float32')
x_val=thesis.NormalizeDataset(x_val)

y_val = y_val.values.astype('float32')
y_val = np.reshape(y_val, (-1, 1))
y_val=thesis.NormalizeDataset(y_val)

# %%
x_test = x_test.values.astype('float32')
x_test=thesis.NormalizeDataset(x_test)

y_test = y_test.values.astype('float32')
y_test = np.reshape(y_test, (-1, 1))
y_test=thesis.NormalizeDataset(y_test)

# %%
window=24
x_train, x_val, x_test = thesis.df_to_numpy_array_features(x_train, x_val, x_test, window)
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (178166, 24, 12)
# (7475, 24, 12)
# (37023, 24, 12)

# %%
y_train, y_val, y_test= thesis.df_to_numpy_array_target(y_train, y_val, y_test, window)
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
y_train
# Out:
# (178166, 1)
# (7475, 1)
# (37023, 1)
# array([[0.24513888],
#        [0.24537253],
#        [0.24533916],
#        ...,
#        [0.8828335 ],
#        [0.8822999 ],
#        [0.8840008 ]], dtype=float32)

# %%
y_train=y_train[:,-1]
y_val=y_val[:,-1]
y_test=y_test[:,-1]
y_train
# Out:
# array([0.24513888, 0.24537253, 0.24533916, ..., 0.8828335 , 0.8822999 ,
#        0.8840008 ], dtype=float32)

# %%
model= thesis.LSTM_Model(x_train)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 24, 256)           275456
#
#  lstm_4 (LSTM)               (None, 24, 64)            82176
#
#  dropout_1 (Dropout)         (None, 24, 64)            0
#
#  lstm_5 (LSTM)               (None, 16)                5184
#
#  dense_3 (Dense)             (None, 32)                544
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dense_5 (Dense)             (None, 1)                 17
#
#  lambda_1 (Lambda)           (None, 1)                 0
#
# =================================================================
# Total params: 363,905
# Trainable params: 363,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

# Set the metric you want to monitor, the threshold, and the patience value
early_stopping = EarlyStopping(monitor='val_mse', patience=30)

checkpoint = ModelCheckpoint("/content/drive/MyDrive/modelweights/JPY_USD5_LSTM", monitor='val_mse', verbose=1, save_best_only=True, mode='min')

# Fit
callbacks_list = [checkpoint, early_stopping ]

Epochs=60
Batch_size=385
history=thesis.CreateHistory(x_train, y_train, x_val, y_val, model, callbacks_list, Epochs, Batch_size)
# Out:
# Epoch 1/60
# 463/463 [==============================] - ETA: 0s - loss: 1064.2526 - mae: 13.1483 - mse: 1064.2526 - root_mean_squared_error: 32.6229 - mape: 18252.4414
# Epoch 1: val_mse improved from inf to 0.51095, saving model to /content/drive/MyDrive/modelweights/JPY_USD5_LSTM
# WARNING:absl:Found untraced functions such as lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_11_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 463/463 [==============================] - 29s 42ms/step - loss: 1064.2526 - mae: 13.1483 - mse: 1064.2526 - root_mean_squared_error: 32.6229 - mape: 18252.4414 - val_loss: 0.5110 - val_mae: 0.6412 - val_mse: 0.5110 - val_root_mean_squared_error: 0.7148 - val_mape: 158961.7500
# Epoch 2/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.3352 - mae: 0.5317 - mse: 0.3352 - root_mean_squared_error: 0.5789 - mape: 5139.9243
# Epoch 2: val_mse improved from 0.51095 to 0.10106, saving model to /content/drive/MyDrive/modelweights/JPY_USD5_LSTM
# WARNING:absl:Found untraced functions such as lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_11_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 463/463 [==============================] - 18s 39ms/step - loss: 0.3348 - mae: 0.5313 - mse: 0.3348 - root_mean_squared_error: 0.5786 - mape: 5131.6787 - val_loss: 0.1011 - val_mae: 0.2836 - val_mse: 0.1011 - val_root_mean_squared_error: 0.3179 - val_mape: 77682.3125
# Epoch 3/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.0803 - mae: 0.2536 - mse: 0.0803 - root_mean_squared_error: 0.2834 - mape: 2956.0984
# Epoch 3: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0803 - mae: 0.2535 - mse: 0.0803 - root_mean_squared_error: 0.2833 - mape: 2951.3618 - val_loss: 0.1147 - val_mae: 0.3119 - val_mse: 0.1147 - val_root_mean_squared_error: 0.3387 - val_mape: 56497.6758
# Epoch 4/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.0466 - mae: 0.1798 - mse: 0.0466 - root_mean_squared_error: 0.2158 - mape: 2217.8650
# Epoch 4: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0466 - mae: 0.1798 - mse: 0.0466 - root_mean_squared_error: 0.2158 - mape: 2214.3206 - val_loss: 0.1361 - val_mae: 0.3306 - val_mse: 0.1361 - val_root_mean_squared_error: 0.3689 - val_mape: 47347.2461
# Epoch 5/60
# 461/463 [============================>.] - ETA: 0s - loss: 0.0392 - mae: 0.1550 - mse: 0.0392 - root_mean_squared_error: 0.1980 - mape: 1924.4730
# Epoch 5: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0392 - mae: 0.1550 - mse: 0.0392 - root_mean_squared_error: 0.1979 - mape: 1917.4120 - val_loss: 0.1502 - val_mae: 0.3434 - val_mse: 0.1502 - val_root_mean_squared_error: 0.3876 - val_mape: 42780.6602
# Epoch 6/60
# 460/463 [============================>.] - ETA: 0s - loss: 0.0374 - mae: 0.1439 - mse: 0.0374 - root_mean_squared_error: 0.1935 - mape: 1756.2445
# Epoch 6: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0374 - mae: 0.1439 - mse: 0.0374 - root_mean_squared_error: 0.1934 - mape: 1746.1936 - val_loss: 0.1581 - val_mae: 0.3506 - val_mse: 0.1581 - val_root_mean_squared_error: 0.3976 - val_mape: 40507.3242
# Epoch 7/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.0371 - mae: 0.1391 - mse: 0.0371 - root_mean_squared_error: 0.1925 - mape: 1934.6555
# Epoch 7: val_mse did not improve from 0.10106
# 463/463 [==============================] - 8s 17ms/step - loss: 0.0371 - mae: 0.1391 - mse: 0.0371 - root_mean_squared_error: 0.1925 - mape: 1931.5500 - val_loss: 0.1619 - val_mae: 0.3539 - val_mse: 0.1619 - val_root_mean_squared_error: 0.4024 - val_mape: 39465.1016
# Epoch 8/60
# 460/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1375 - mse: 0.0370 - root_mean_squared_error: 0.1924 - mape: 1979.9995
# Epoch 8: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 16ms/step - loss: 0.0370 - mae: 0.1375 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1968.5494 - val_loss: 0.1637 - val_mae: 0.3554 - val_mse: 0.1637 - val_root_mean_squared_error: 0.4046 - val_mape: 38994.8633
# Epoch 9/60
# 463/463 [==============================] - ETA: 0s - loss: 0.0370 - mae: 0.1368 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1784.2266
# Epoch 9: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 16ms/step - loss: 0.0370 - mae: 0.1368 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1784.2266 - val_loss: 0.1640 - val_mae: 0.3557 - val_mse: 0.1640 - val_root_mean_squared_error: 0.4049 - val_mape: 38920.5156
# Epoch 10/60
# 460/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1368 - mse: 0.0370 - root_mean_squared_error: 0.1924 - mape: 1866.8103
# Epoch 10: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 16ms/step - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1856.0192 - val_loss: 0.1640 - val_mae: 0.3557 - val_mse: 0.1640 - val_root_mean_squared_error: 0.4050 - val_mape: 38907.0195
# Epoch 11/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1368 - mse: 0.0370 - root_mean_squared_error: 0.1924 - mape: 1671.4276
# Epoch 11: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0370 - mae: 0.1368 - mse: 0.0370 - root_mean_squared_error: 0.1924 - mape: 1668.7556 - val_loss: 0.1642 - val_mae: 0.3559 - val_mse: 0.1642 - val_root_mean_squared_error: 0.4052 - val_mape: 38851.6797
# Epoch 12/60
# 463/463 [==============================] - ETA: 0s - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1924 - mape: 1811.9729
# Epoch 12: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1924 - mape: 1811.9729 - val_loss: 0.1641 - val_mae: 0.3558 - val_mse: 0.1641 - val_root_mean_squared_error: 0.4050 - val_mape: 38895.5625
# Epoch 13/60
# 460/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1366 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1721.3124
# Epoch 13: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0370 - mae: 0.1366 - mse: 0.0370 - root_mean_squared_error: 0.1922 - mape: 1711.4014 - val_loss: 0.1641 - val_mae: 0.3558 - val_mse: 0.1641 - val_root_mean_squared_error: 0.4051 - val_mape: 38879.4102
# Epoch 14/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1663.7228
# Epoch 14: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1661.0770 - val_loss: 0.1638 - val_mae: 0.3555 - val_mse: 0.1638 - val_root_mean_squared_error: 0.4047 - val_mape: 38971.8242
# Epoch 15/60
# 460/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1366 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1806.3282
# Epoch 15: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0370 - mae: 0.1366 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1795.9142 - val_loss: 0.1640 - val_mae: 0.3557 - val_mse: 0.1640 - val_root_mean_squared_error: 0.4050 - val_mape: 38903.3828
# Epoch 16/60
# 460/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1745.7200
# Epoch 16: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1735.6793 - val_loss: 0.1638 - val_mae: 0.3556 - val_mse: 0.1638 - val_root_mean_squared_error: 0.4048 - val_mape: 38954.1953
# Epoch 17/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1366 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1722.4540
# Epoch 17: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0370 - mae: 0.1366 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1719.7041 - val_loss: 0.1631 - val_mae: 0.3549 - val_mse: 0.1631 - val_root_mean_squared_error: 0.4038 - val_mape: 39152.1094
# Epoch 18/60
# 463/463 [==============================] - ETA: 0s - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1650.7218
# Epoch 18: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1650.7218 - val_loss: 0.1644 - val_mae: 0.3561 - val_mse: 0.1644 - val_root_mean_squared_error: 0.4055 - val_mape: 38797.7500
# Epoch 19/60
# 460/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1366 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1753.1660
# Epoch 19: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1924 - mape: 1743.0684 - val_loss: 0.1641 - val_mae: 0.3558 - val_mse: 0.1641 - val_root_mean_squared_error: 0.4051 - val_mape: 38889.9258
# Epoch 20/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1366 - mse: 0.0370 - root_mean_squared_error: 0.1922 - mape: 1689.4082
# Epoch 20: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0370 - mae: 0.1366 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1686.7095 - val_loss: 0.1638 - val_mae: 0.3556 - val_mse: 0.1638 - val_root_mean_squared_error: 0.4048 - val_mape: 38949.2500
# Epoch 21/60
# 461/463 [============================>.] - ETA: 0s - loss: 0.0369 - mae: 0.1366 - mse: 0.0369 - root_mean_squared_error: 0.1922 - mape: 1737.4504
# Epoch 21: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0370 - mae: 0.1366 - mse: 0.0370 - root_mean_squared_error: 0.1922 - mape: 1731.0613 - val_loss: 0.1640 - val_mae: 0.3558 - val_mse: 0.1640 - val_root_mean_squared_error: 0.4050 - val_mape: 38895.9531
# Epoch 22/60
# 460/463 [============================>.] - ETA: 0s - loss: 0.0369 - mae: 0.1366 - mse: 0.0369 - root_mean_squared_error: 0.1922 - mape: 1691.7518
# Epoch 22: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0369 - mae: 0.1366 - mse: 0.0369 - root_mean_squared_error: 0.1922 - mape: 1682.0295 - val_loss: 0.1640 - val_mae: 0.3557 - val_mse: 0.1640 - val_root_mean_squared_error: 0.4050 - val_mape: 38910.0000
# Epoch 23/60
# 461/463 [============================>.] - ETA: 0s - loss: 0.0369 - mae: 0.1366 - mse: 0.0369 - root_mean_squared_error: 0.1922 - mape: 1717.2267
# Epoch 23: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0369 - mae: 0.1366 - mse: 0.0369 - root_mean_squared_error: 0.1922 - mape: 1710.9010 - val_loss: 0.1609 - val_mae: 0.3530 - val_mse: 0.1609 - val_root_mean_squared_error: 0.4011 - val_mape: 39745.2852
# Epoch 24/60
# 463/463 [==============================] - ETA: 0s - loss: 0.0369 - mae: 0.1367 - mse: 0.0369 - root_mean_squared_error: 0.1922 - mape: 1666.9242
# Epoch 24: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0369 - mae: 0.1367 - mse: 0.0369 - root_mean_squared_error: 0.1922 - mape: 1666.9242 - val_loss: 0.1623 - val_mae: 0.3542 - val_mse: 0.1623 - val_root_mean_squared_error: 0.4028 - val_mape: 39366.2969
# Epoch 25/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1923 - mape: 1729.4429
# Epoch 25: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 16ms/step - loss: 0.0370 - mae: 0.1367 - mse: 0.0370 - root_mean_squared_error: 0.1922 - mape: 1726.6720 - val_loss: 0.1631 - val_mae: 0.3549 - val_mse: 0.1631 - val_root_mean_squared_error: 0.4039 - val_mape: 39142.7734
# Epoch 26/60
# 461/463 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1366 - mse: 0.0370 - root_mean_squared_error: 0.1922 - mape: 1689.6716
# Epoch 26: val_mse did not improve from 0.10106
# 463/463 [==============================] - 8s 17ms/step - loss: 0.0369 - mae: 0.1366 - mse: 0.0369 - root_mean_squared_error: 0.1922 - mape: 1683.4650 - val_loss: 0.1635 - val_mae: 0.3553 - val_mse: 0.1635 - val_root_mean_squared_error: 0.4043 - val_mape: 39042.4727
# Epoch 27/60
# 460/463 [============================>.] - ETA: 0s - loss: 0.0369 - mae: 0.1365 - mse: 0.0369 - root_mean_squared_error: 0.1921 - mape: 1700.1699
# Epoch 27: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0369 - mae: 0.1365 - mse: 0.0369 - root_mean_squared_error: 0.1921 - mape: 1690.3940 - val_loss: 0.1621 - val_mae: 0.3541 - val_mse: 0.1621 - val_root_mean_squared_error: 0.4026 - val_mape: 39413.0664
# Epoch 28/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.0369 - mae: 0.1365 - mse: 0.0369 - root_mean_squared_error: 0.1921 - mape: 1661.3423
# Epoch 28: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0369 - mae: 0.1365 - mse: 0.0369 - root_mean_squared_error: 0.1921 - mape: 1658.6820 - val_loss: 0.1620 - val_mae: 0.3540 - val_mse: 0.1620 - val_root_mean_squared_error: 0.4025 - val_mape: 39431.3477
# Epoch 29/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.0369 - mae: 0.1366 - mse: 0.0369 - root_mean_squared_error: 0.1921 - mape: 1646.3748
# Epoch 29: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0369 - mae: 0.1365 - mse: 0.0369 - root_mean_squared_error: 0.1921 - mape: 1643.7489 - val_loss: 0.1643 - val_mae: 0.3559 - val_mse: 0.1643 - val_root_mean_squared_error: 0.4053 - val_mape: 38826.4414
# Epoch 30/60
# 461/463 [============================>.] - ETA: 0s - loss: 0.0369 - mae: 0.1365 - mse: 0.0369 - root_mean_squared_error: 0.1920 - mape: 1654.7152
# Epoch 30: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 15ms/step - loss: 0.0369 - mae: 0.1364 - mse: 0.0369 - root_mean_squared_error: 0.1920 - mape: 1648.6473 - val_loss: 0.1650 - val_mae: 0.3566 - val_mse: 0.1650 - val_root_mean_squared_error: 0.4063 - val_mape: 38610.6523
# Epoch 31/60
# 462/463 [============================>.] - ETA: 0s - loss: 0.0369 - mae: 0.1365 - mse: 0.0369 - root_mean_squared_error: 0.1920 - mape: 2222.0420
# Epoch 31: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 16ms/step - loss: 0.0369 - mae: 0.1365 - mse: 0.0369 - root_mean_squared_error: 0.1920 - mape: 2218.4763 - val_loss: 0.1639 - val_mae: 0.3556 - val_mse: 0.1639 - val_root_mean_squared_error: 0.4049 - val_mape: 38847.0977
# Epoch 32/60
# 461/463 [============================>.] - ETA: 0s - loss: 0.0368 - mae: 0.1362 - mse: 0.0368 - root_mean_squared_error: 0.1917 - mape: 1735.3284
# Epoch 32: val_mse did not improve from 0.10106
# 463/463 [==============================] - 7s 16ms/step - loss: 0.0368 - mae: 0.1362 - mse: 0.0368 - root_mean_squared_error: 0.1918 - mape: 1728.9603 - val_loss: 0.1613 - val_mae: 0.3531 - val_mse: 0.1613 - val_root_mean_squared_error: 0.4017 - val_mape: 39300.5156

# %%
thesis.SummarizeHistory(history)

# %%
print(min(history.history['val_mae']))
print(min(history.history['val_root_mean_squared_error']))
#print(min(histroy.history['val_mape']))
r2_scr = thesis.R_Squared_Score(model, x_val, y_val)
print(r2_scr)

# %%
early_stopping = EarlyStopping(monitor='val_mse', patience=12)

# %%
model.load_weights("/content/drive/MyDrive/modelweights/JPY_USD5_LSTM")

from keras.callbacks import LearningRateScheduler
import keras.backend as K

def scheduler(epoch):
    if epoch%2==0 and epoch!=0:
        lr = K.get_value(model.optimizer.lr)
        K.set_value(model.optimizer.lr, lr*.9)
        print("lr changed to {}".format(lr*.9))
    return K.get_value(model.optimizer.lr)
lr_decay = LearningRateScheduler(scheduler)

callbacks_list = [checkpoint, lr_decay, early_stopping]

Epochs=20
Batch_size=385
history=thesis.CreateHistory(x_train, y_train, x_val, y_val, model, callbacks_list, Epochs, Batch_size)
# Out:
# Epoch 1/20
# 462/463 [============================>.] - ETA: 0s - loss: 0.0134 - mae: 0.0615 - mse: 0.0134 - root_mean_squared_error: 0.1156 - mape: 773.7531
# Epoch 1: val_mse improved from 0.10106 to 0.00174, saving model to /content/drive/MyDrive/modelweights/JPY_USD5_LSTM
# WARNING:absl:Found untraced functions such as lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_11_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 463/463 [==============================] - 23s 41ms/step - loss: 0.0133 - mae: 0.0615 - mse: 0.0133 - root_mean_squared_error: 0.1155 - mape: 772.4759 - val_loss: 0.0017 - val_mae: 0.0363 - val_mse: 0.0017 - val_root_mean_squared_error: 0.0417 - val_mape: 13671.9990 - lr: 0.0010
# Epoch 2/20
# 461/463 [============================>.] - ETA: 0s - loss: 1.7590e-04 - mae: 0.0095 - mse: 1.7590e-04 - root_mean_squared_error: 0.0133 - mape: 509.8499
# Epoch 2: val_mse did not improve from 0.00174
# 463/463 [==============================] - 7s 15ms/step - loss: 1.7567e-04 - mae: 0.0095 - mse: 1.7567e-04 - root_mean_squared_error: 0.0133 - mape: 507.9140 - val_loss: 0.0019 - val_mae: 0.0371 - val_mse: 0.0019 - val_root_mean_squared_error: 0.0437 - val_mape: 12103.4727 - lr: 0.0010
# lr changed to 0.0009000000427477062
# Epoch 3/20
# 463/463 [==============================] - ETA: 0s - loss: 9.6662e-05 - mae: 0.0071 - mse: 9.6662e-05 - root_mean_squared_error: 0.0098 - mape: 409.5443
# Epoch 3: val_mse did not improve from 0.00174
# 463/463 [==============================] - 8s 17ms/step - loss: 9.6662e-05 - mae: 0.0071 - mse: 9.6662e-05 - root_mean_squared_error: 0.0098 - mape: 409.5443 - val_loss: 0.0019 - val_mae: 0.0365 - val_mse: 0.0019 - val_root_mean_squared_error: 0.0430 - val_mape: 11674.3584 - lr: 9.0000e-04
# Epoch 4/20
# 460/463 [============================>.] - ETA: 0s - loss: 7.1974e-05 - mae: 0.0062 - mse: 7.1974e-05 - root_mean_squared_error: 0.0085 - mape: 402.1117
# Epoch 4: val_mse improved from 0.00174 to 0.00138, saving model to /content/drive/MyDrive/modelweights/JPY_USD5_LSTM
# WARNING:absl:Found untraced functions such as lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_11_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 463/463 [==============================] - 18s 39ms/step - loss: 7.1955e-05 - mae: 0.0062 - mse: 7.1955e-05 - root_mean_squared_error: 0.0085 - mape: 399.7247 - val_loss: 0.0014 - val_mae: 0.0301 - val_mse: 0.0014 - val_root_mean_squared_error: 0.0371 - val_mape: 11773.2686 - lr: 9.0000e-04
# lr changed to 0.0008100000384729356
# Epoch 5/20
# 462/463 [============================>.] - ETA: 0s - loss: 5.8503e-05 - mae: 0.0056 - mse: 5.8503e-05 - root_mean_squared_error: 0.0076 - mape: 388.0900
# Epoch 5: val_mse did not improve from 0.00138
# 463/463 [==============================] - 7s 16ms/step - loss: 5.8496e-05 - mae: 0.0056 - mse: 5.8496e-05 - root_mean_squared_error: 0.0076 - mape: 387.4503 - val_loss: 0.0020 - val_mae: 0.0382 - val_mse: 0.0020 - val_root_mean_squared_error: 0.0452 - val_mape: 12299.9561 - lr: 8.1000e-04
# Epoch 6/20
# 463/463 [==============================] - ETA: 0s - loss: 5.6707e-05 - mae: 0.0054 - mse: 5.6707e-05 - root_mean_squared_error: 0.0075 - mape: 358.6466
# Epoch 6: val_mse did not improve from 0.00138
# 463/463 [==============================] - 7s 16ms/step - loss: 5.6707e-05 - mae: 0.0054 - mse: 5.6707e-05 - root_mean_squared_error: 0.0075 - mape: 358.6466 - val_loss: 0.0015 - val_mae: 0.0320 - val_mse: 0.0015 - val_root_mean_squared_error: 0.0391 - val_mape: 11487.1309 - lr: 8.1000e-04
# lr changed to 0.0007290000503417104
# Epoch 7/20
# 462/463 [============================>.] - ETA: 0s - loss: 4.4768e-05 - mae: 0.0048 - mse: 4.4768e-05 - root_mean_squared_error: 0.0067 - mape: 355.6335
# Epoch 7: val_mse improved from 0.00138 to 0.00128, saving model to /content/drive/MyDrive/modelweights/JPY_USD5_LSTM
# WARNING:absl:Found untraced functions such as lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_11_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 463/463 [==============================] - 19s 42ms/step - loss: 4.4744e-05 - mae: 0.0048 - mse: 4.4744e-05 - root_mean_squared_error: 0.0067 - mape: 355.0454 - val_loss: 0.0013 - val_mae: 0.0292 - val_mse: 0.0013 - val_root_mean_squared_error: 0.0358 - val_mape: 10241.4287 - lr: 7.2900e-04
# Epoch 8/20
# 463/463 [==============================] - ETA: 0s - loss: 4.4295e-05 - mae: 0.0048 - mse: 4.4295e-05 - root_mean_squared_error: 0.0067 - mape: 346.4302
# Epoch 8: val_mse did not improve from 0.00128
# 463/463 [==============================] - 7s 16ms/step - loss: 4.4295e-05 - mae: 0.0048 - mse: 4.4295e-05 - root_mean_squared_error: 0.0067 - mape: 346.4302 - val_loss: 0.0554 - val_mae: 0.0442 - val_mse: 0.0554 - val_root_mean_squared_error: 0.2354 - val_mape: 9890.3496 - lr: 7.2900e-04
# lr changed to 0.0006561000715009868
# Epoch 9/20
# 461/463 [============================>.] - ETA: 0s - loss: 4.4033e-05 - mae: 0.0048 - mse: 4.4033e-05 - root_mean_squared_error: 0.0066 - mape: 333.4924
# Epoch 9: val_mse did not improve from 0.00128
# 463/463 [==============================] - 7s 15ms/step - loss: 4.4043e-05 - mae: 0.0048 - mse: 4.4043e-05 - root_mean_squared_error: 0.0066 - mape: 332.2267 - val_loss: 0.0021 - val_mae: 0.0360 - val_mse: 0.0021 - val_root_mean_squared_error: 0.0454 - val_mape: 9776.5459 - lr: 6.5610e-04
# Epoch 10/20
# 463/463 [==============================] - ETA: 0s - loss: 3.7613e-05 - mae: 0.0044 - mse: 3.7613e-05 - root_mean_squared_error: 0.0061 - mape: 327.6390
# Epoch 10: val_mse did not improve from 0.00128
# 463/463 [==============================] - 7s 16ms/step - loss: 3.7613e-05 - mae: 0.0044 - mse: 3.7613e-05 - root_mean_squared_error: 0.0061 - mape: 327.6390 - val_loss: 0.0017 - val_mae: 0.0349 - val_mse: 0.0017 - val_root_mean_squared_error: 0.0411 - val_mape: 9693.2725 - lr: 6.5610e-04
# lr changed to 0.0005904900433961303
# Epoch 11/20
# 461/463 [============================>.] - ETA: 0s - loss: 3.3823e-05 - mae: 0.0042 - mse: 3.3823e-05 - root_mean_squared_error: 0.0058 - mape: 315.6023
# Epoch 11: val_mse did not improve from 0.00128
# 463/463 [==============================] - 7s 15ms/step - loss: 3.3781e-05 - mae: 0.0042 - mse: 3.3781e-05 - root_mean_squared_error: 0.0058 - mape: 314.4024 - val_loss: 0.0014 - val_mae: 0.0318 - val_mse: 0.0014 - val_root_mean_squared_error: 0.0381 - val_mape: 8785.8555 - lr: 5.9049e-04
# Epoch 12/20
# 462/463 [============================>.] - ETA: 0s - loss: 3.5124e-05 - mae: 0.0043 - mse: 3.5124e-05 - root_mean_squared_error: 0.0059 - mape: 306.5576
# Epoch 12: val_mse did not improve from 0.00128
# 463/463 [==============================] - 7s 16ms/step - loss: 3.5128e-05 - mae: 0.0043 - mse: 3.5128e-05 - root_mean_squared_error: 0.0059 - mape: 306.0516 - val_loss: 0.0018 - val_mae: 0.0375 - val_mse: 0.0018 - val_root_mean_squared_error: 0.0429 - val_mape: 7827.4106 - lr: 5.9049e-04
# lr changed to 0.0005314410547725857
# Epoch 13/20
# 463/463 [==============================] - ETA: 0s - loss: 3.0889e-05 - mae: 0.0040 - mse: 3.0889e-05 - root_mean_squared_error: 0.0056 - mape: 301.1488
# Epoch 13: val_mse improved from 0.00128 to 0.00108, saving model to /content/drive/MyDrive/modelweights/JPY_USD5_LSTM
# WARNING:absl:Found untraced functions such as lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_11_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 463/463 [==============================] - 18s 39ms/step - loss: 3.0889e-05 - mae: 0.0040 - mse: 3.0889e-05 - root_mean_squared_error: 0.0056 - mape: 301.1488 - val_loss: 0.0011 - val_mae: 0.0270 - val_mse: 0.0011 - val_root_mean_squared_error: 0.0329 - val_mape: 7284.7954 - lr: 5.3144e-04
# Epoch 14/20
# 460/463 [============================>.] - ETA: 0s - loss: 3.1203e-05 - mae: 0.0040 - mse: 3.1203e-05 - root_mean_squared_error: 0.0056 - mape: 298.9964
# Epoch 14: val_mse did not improve from 0.00108
# 463/463 [==============================] - 7s 15ms/step - loss: 3.1162e-05 - mae: 0.0040 - mse: 3.1162e-05 - root_mean_squared_error: 0.0056 - mape: 297.2175 - val_loss: 0.0015 - val_mae: 0.0338 - val_mse: 0.0015 - val_root_mean_squared_error: 0.0390 - val_mape: 7687.6982 - lr: 5.3144e-04
# lr changed to 0.00047829695977270604
# Epoch 15/20
# 462/463 [============================>.] - ETA: 0s - loss: 2.6492e-05 - mae: 0.0037 - mse: 2.6492e-05 - root_mean_squared_error: 0.0051 - mape: 293.7459
# Epoch 15: val_mse did not improve from 0.00108
# 463/463 [==============================] - 7s 15ms/step - loss: 2.6506e-05 - mae: 0.0037 - mse: 2.6506e-05 - root_mean_squared_error: 0.0051 - mape: 293.2614 - val_loss: 0.0017 - val_mae: 0.0366 - val_mse: 0.0017 - val_root_mean_squared_error: 0.0417 - val_mape: 7150.2827 - lr: 4.7830e-04
# Epoch 16/20
# 462/463 [============================>.] - ETA: 0s - loss: 2.9370e-05 - mae: 0.0039 - mse: 2.9370e-05 - root_mean_squared_error: 0.0054 - mape: 302.9420
# Epoch 16: val_mse did not improve from 0.00108
# 463/463 [==============================] - 7s 15ms/step - loss: 2.9356e-05 - mae: 0.0039 - mse: 2.9356e-05 - root_mean_squared_error: 0.0054 - mape: 302.4411 - val_loss: 0.0018 - val_mae: 0.0379 - val_mse: 0.0018 - val_root_mean_squared_error: 0.0428 - val_mape: 9287.6729 - lr: 4.7830e-04
# lr changed to 0.0004304672533180565
# Epoch 17/20
# 461/463 [============================>.] - ETA: 0s - loss: 2.3503e-05 - mae: 0.0035 - mse: 2.3503e-05 - root_mean_squared_error: 0.0048 - mape: 286.6722
# Epoch 17: val_mse did not improve from 0.00108
# 463/463 [==============================] - 7s 16ms/step - loss: 2.3509e-05 - mae: 0.0035 - mse: 2.3509e-05 - root_mean_squared_error: 0.0048 - mape: 285.5823 - val_loss: 0.0016 - val_mae: 0.0345 - val_mse: 0.0016 - val_root_mean_squared_error: 0.0401 - val_mape: 11195.6465 - lr: 4.3047e-04
# Epoch 18/20
# 461/463 [============================>.] - ETA: 0s - loss: 2.2429e-05 - mae: 0.0034 - mse: 2.2429e-05 - root_mean_squared_error: 0.0047 - mape: 284.0757
# Epoch 18: val_mse did not improve from 0.00108
# 463/463 [==============================] - 7s 15ms/step - loss: 2.2457e-05 - mae: 0.0034 - mse: 2.2457e-05 - root_mean_squared_error: 0.0047 - mape: 282.9961 - val_loss: 0.0014 - val_mae: 0.0323 - val_mse: 0.0014 - val_root_mean_squared_error: 0.0375 - val_mape: 10025.4570 - lr: 4.3047e-04
# lr changed to 0.00038742052274756136
# Epoch 19/20
# 461/463 [============================>.] - ETA: 0s - loss: 1.9578e-05 - mae: 0.0032 - mse: 1.9578e-05 - root_mean_squared_error: 0.0044 - mape: 282.8738
# Epoch 19: val_mse did not improve from 0.00108
# 463/463 [==============================] - 7s 15ms/step - loss: 1.9572e-05 - mae: 0.0032 - mse: 1.9572e-05 - root_mean_squared_error: 0.0044 - mape: 281.7979 - val_loss: 0.0018 - val_mae: 0.0367 - val_mse: 0.0018 - val_root_mean_squared_error: 0.0423 - val_mape: 10912.3564 - lr: 3.8742e-04
# Epoch 20/20
# 463/463 [==============================] - ETA: 0s - loss: 2.0299e-05 - mae: 0.0033 - mse: 2.0299e-05 - root_mean_squared_error: 0.0045 - mape: 265.7815
# Epoch 20: val_mse did not improve from 0.00108
# 463/463 [==============================] - 7s 15ms/step - loss: 2.0299e-05 - mae: 0.0033 - mse: 2.0299e-05 - root_mean_squared_error: 0.0045 - mape: 265.7815 - val_loss: 0.0016 - val_mae: 0.0348 - val_mse: 0.0016 - val_root_mean_squared_error: 0.0405 - val_mape: 12724.3555 - lr: 3.8742e-04

# %%
thesis.SummarizeHistory(history)

# %%
print(min(history.history['val_mae']))
print(min(history.history['val_root_mean_squared_error']))
#print(min(histroy.history['val_mape']))
r2_scr = thesis.R_Squared_Score(model, x_val, y_val)
print(r2_scr)
# Out:
# 0.027040015906095505
# 0.032910071313381195
# 234/234 [==============================] - 2s 4ms/step
# 0.9835776075268179

# %%
model.load_weights("/content/drive/MyDrive/modelweights/JPY_USD5_LSTM")
val_predictions=thesis.CreatPrediction(model,x_val, y_val)
# Out:
# 234/234 [==============================] - 1s 4ms/step

# %%
val_predictions['diff'] = val_predictions['predicted'] - val_predictions['actual']
plt.figure(figsize=(10,10))
sns.distplot(val_predictions['diff']);
plt.title('Distribution of differences between actual and prediction for validation')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
predictions=thesis.CreatPrediction(model,x_test, y_test)
# Out:
# 1157/1157 [==============================] - 5s 4ms/step

# %%
predictions['diff'] = predictions['predicted'] - predictions['actual']
plt.figure(figsize=(10,10))
sns.distplot(predictions['diff']);
plt.title('Distribution of differences between actual and prediction')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print("MSE : ", mean_squared_error(predictions['predicted'].values, predictions['actual'].values))
print("MAE : ", mean_absolute_error(predictions['predicted'].values, predictions['actual'].values))
from math import sqrt

print('RMSE  :', sqrt(mean_squared_error(predictions['predicted'].values, predictions['actual'].values)))

test_r2_scr = thesis.R_Squared_Score(model, x_test, y_test)
print('R2_Score  :',test_r2_scr)


predictions['diff'].describe()
# Out:
# MSE :  0.00026189520981109455
# MAE :  0.010478465477442802
# RMSE  : 0.016183176752760705
# 1157/1157 [==============================] - 5s 4ms/step
# R2_Score  : 0.9950809106012001
# count    37023.000000
# mean         0.002473
# std          0.015993
# min         -0.123305
# 25%         -0.005583
# 50%          0.001046
# 75%          0.009683
# max          0.222957
# Name: diff, dtype: float64
