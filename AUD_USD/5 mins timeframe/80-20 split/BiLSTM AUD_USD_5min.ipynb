# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
import pickle
import joblib

# %%
# !cp /content/drive/MyDrive/thesis.py /content

# %%
import thesis
#def IMPORT():
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

# %%
df = pd.read_csv('/content/drive/MyDrive/Thesis Dataset/AUD_USD_5min.csv')
df.dropna(inplace=True)
df['timestamp'] = pd.to_datetime(df['timestamp'], infer_datetime_format=True)

df.set_index('timestamp', inplace=True)
print(df.shape)
df.head()
# Out:
# (222691, 4)
#                         open    close      low     high
# timestamp
# 2020-01-01 17:00:00  0.70137  0.70134  0.70127  0.70137
# 2020-01-01 17:05:00  0.70127  0.70111  0.70086  0.70139
# 2020-01-01 17:10:00  0.70113  0.70112  0.70093  0.70132
# 2020-01-01 17:15:00  0.70112  0.70088  0.70084  0.70126
# 2020-01-01 17:20:00  0.70088  0.70114  0.70078  0.70159

# %%
df=thesis.AddingColumn(df)
print(df.shape)
df.head()
# Out:
# /content/thesis.py:42: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df['week'] = df.index.week
# (222690, 12)
#                         open    close      low     high  previous_close  hour  \
# timestamp
# 2020-01-01 17:00:00  0.70137  0.70134  0.70127  0.70137         0.70111    17
# 2020-01-01 17:05:00  0.70127  0.70111  0.70086  0.70139         0.70112    17
# 2020-01-01 17:10:00  0.70113  0.70112  0.70093  0.70132         0.70088    17
# 2020-01-01 17:15:00  0.70112  0.70088  0.70084  0.70126         0.70114    17
# 2020-01-01 17:20:00  0.70088  0.70114  0.70078  0.70159         0.70095    17
#
#                      day  week  momentum  avg_price    range  ohlc_price
# timestamp
# 2020-01-01 17:00:00    2     1   0.00003   0.701320  0.00010    0.701337
# 2020-01-01 17:05:00    2     1   0.00016   0.701125  0.00053    0.701157
# 2020-01-01 17:10:00    2     1   0.00001   0.701125  0.00039    0.701125
# 2020-01-01 17:15:00    2     1   0.00024   0.701050  0.00042    0.701025
# 2020-01-01 17:20:00    2     1  -0.00026   0.701185  0.00081    0.701098

# %%
df=thesis.ApplyPCA(df)
df.head()
# Out:
#                         open    close      low     high  previous_close  hour  \
# timestamp
# 2020-01-01 17:00:00  0.70137  0.70134  0.70127  0.70137         0.70111    17
# 2020-01-01 17:05:00  0.70127  0.70111  0.70086  0.70139         0.70112    17
# 2020-01-01 17:10:00  0.70113  0.70112  0.70093  0.70132         0.70088    17
# 2020-01-01 17:15:00  0.70112  0.70088  0.70084  0.70126         0.70114    17
# 2020-01-01 17:20:00  0.70088  0.70114  0.70078  0.70159         0.70095    17
#
#                      day  week  momentum  avg_price    range  ohlc_price  \
# timestamp
# 2020-01-01 17:00:00    2     1   0.00003   0.701320  0.00010    0.701337
# 2020-01-01 17:05:00    2     1   0.00016   0.701125  0.00053    0.701157
# 2020-01-01 17:10:00    2     1   0.00001   0.701125  0.00039    0.701125
# 2020-01-01 17:15:00    2     1   0.00024   0.701050  0.00042    0.701025
# 2020-01-01 17:20:00    2     1  -0.00026   0.701185  0.00081    0.701098
#
#                            pca
# timestamp
# 2020-01-01 17:00:00 -25.514885
# 2020-01-01 17:05:00 -25.514740
# 2020-01-01 17:10:00 -25.514740
# 2020-01-01 17:15:00 -25.514740
# 2020-01-01 17:20:00 -25.514740

# %%
X = df.drop('close', axis=1)
print(X.head())
y=pd.DataFrame(df['close'])
print(y.head())
# Out:
#                         open      low     high  previous_close  hour  day  \
# timestamp
# 2020-01-01 17:00:00  0.70137  0.70127  0.70137         0.70111    17    2
# 2020-01-01 17:05:00  0.70127  0.70086  0.70139         0.70112    17    2
# 2020-01-01 17:10:00  0.70113  0.70093  0.70132         0.70088    17    2
# 2020-01-01 17:15:00  0.70112  0.70084  0.70126         0.70114    17    2
# 2020-01-01 17:20:00  0.70088  0.70078  0.70159         0.70095    17    2
#
#                      week  momentum  avg_price    range  ohlc_price        pca
# timestamp
# 2020-01-01 17:00:00     1   0.00003   0.701320  0.00010    0.701337 -25.514885
# 2020-01-01 17:05:00     1   0.00016   0.701125  0.00053    0.701157 -25.514740
# 2020-01-01 17:10:00     1   0.00001   0.701125  0.00039    0.701125 -25.514740
# 2020-01-01 17:15:00     1   0.00024   0.701050  0.00042    0.701025 -25.514740
# 2020-01-01 17:20:00     1  -0.00026   0.701185  0.00081    0.701098 -25.514740
#                        close
# timestamp
# 2020-01-01 17:00:00  0.70134
# 2020-01-01 17:05:00  0.70111
# 2020-01-01 17:10:00  0.70112
# 2020-01-01 17:15:00  0.70088
# 2020-01-01 17:20:00  0.70114

# %%
x_train, y_train, x_val, y_val, x_test, y_test = thesis.Train_Val_Test_split_5Min(X,y)
# Out:
# 178152
# 178152
# 22000
# 22000
# 22538
# 22538

# %%
x_train = x_train.values.astype('float32')
x_train=thesis.NormalizeDataset(x_train)

y_train = y_train.values.astype('float32')
y_train = np.reshape(y_train, (-1, 1))
y_train=thesis.NormalizeDataset(y_train)

x_train.shape
# Out:
# (178152, 12)

# %%
x_val = x_val.values.astype('float32')
x_val=thesis.NormalizeDataset(x_val)

y_val = y_val.values.astype('float32')
y_val = np.reshape(y_val, (-1, 1))
y_val=thesis.NormalizeDataset(y_val)

# %%
x_test = x_test.values.astype('float32')
x_test=thesis.NormalizeDataset(x_test)

y_test = y_test.values.astype('float32')
y_test = np.reshape(y_test, (-1, 1))
y_test=thesis.NormalizeDataset(y_test)

# %%
window=24
x_train, x_val, x_test = thesis.df_to_numpy_array_features(x_train, x_val, x_test, window)
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (178127, 24, 12)
# (21975, 24, 12)
# (22513, 24, 12)

# %%
y_train, y_val, y_test= thesis.df_to_numpy_array_target(y_train, y_val, y_test, window)
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
y_train
# Out:
# (178127, 1)
# (21975, 1)
# (22513, 1)
# array([[0.60305166],
#        [0.6032524 ],
#        [0.60252976],
#        ...,
#        [0.632082  ],
#        [0.63103795],
#        [0.63147974]], dtype=float32)

# %%
y_train=y_train[:,-1]
y_val=y_val[:,-1]
y_test=y_test[:,-1]
y_train
# Out:
# array([0.60305166, 0.6032524 , 0.60252976, ..., 0.632082  , 0.63103795,
#        0.63147974], dtype=float32)

# %%
TargetIndex = df.columns.tolist().index('close')
HighIndex = df.columns.tolist().index('high')
LowIndex = df.columns.tolist().index('low')

# %%
model= thesis.LSTM_Model(x_train)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 256)           275456
#
#  lstm_1 (LSTM)               (None, 24, 64)            82176
#
#  dropout_1 (Dropout)         (None, 24, 64)            0
#
#  lstm_2 (LSTM)               (None, 16)                5184
#
#  dense_3 (Dense)             (None, 32)                544
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dense_5 (Dense)             (None, 1)                 17
#
#  lambda_1 (Lambda)           (None, 1)                 0
#
# =================================================================
# Total params: 363,905
# Trainable params: 363,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint


from tensorflow.keras.callbacks import EarlyStopping

# Set the metric you want to monitor, the threshold, and the patience value
early_stopping = EarlyStopping(monitor='val_mse', patience=30)

checkpoint = ModelCheckpoint("/content/drive/MyDrive/Thesis Dataset/AUD5minGRU.hdf5", monitor='val_mse', verbose=1, save_best_only=True, mode='min')

# Fit
callbacks_list = [checkpoint, early_stopping ]

Epochs=60
Batch_size=385
history=thesis.CreateHistory(x_train, y_train, x_val, y_val, model, callbacks_list, Epochs, Batch_size)
# Out:
# Epoch 1/60
# 463/463 [==============================] - ETA: 0s - loss: 0.0215 - mae: 0.0844 - mse: 0.0215 - root_mean_squared_error: 0.1466 - mape: 3466.7542
# Epoch 1: val_mse improved from inf to 0.00213, saving model to /content/drive/MyDrive/Thesis Dataset/AUD5minGRU.hdf5
# 463/463 [==============================] - 291s 614ms/step - loss: 0.0215 - mae: 0.0844 - mse: 0.0215 - root_mean_squared_error: 0.1466 - mape: 3466.7542 - val_loss: 0.0021 - val_mae: 0.0296 - val_mse: 0.0021 - val_root_mean_squared_error: 0.0461 - val_mape: 11422.6133
# Epoch 2/60
# 463/463 [==============================] - ETA: 0s - loss: 8.7520e-04 - mae: 0.0225 - mse: 8.7520e-04 - root_mean_squared_error: 0.0296 - mape: 985.3023
# Epoch 2: val_mse improved from 0.00213 to 0.00100, saving model to /content/drive/MyDrive/Thesis Dataset/AUD5minGRU.hdf5
# 463/463 [==============================] - 303s 655ms/step - loss: 8.7520e-04 - mae: 0.0225 - mse: 8.7520e-04 - root_mean_squared_error: 0.0296 - mape: 985.3023 - val_loss: 0.0010 - val_mae: 0.0235 - val_mse: 0.0010 - val_root_mean_squared_error: 0.0317 - val_mape: 7642.8618
# Epoch 3/60
# 463/463 [==============================] - ETA: 0s - loss: 3.9294e-04 - mae: 0.0153 - mse: 3.9294e-04 - root_mean_squared_error: 0.0198 - mape: 955.6528
# Epoch 3: val_mse improved from 0.00100 to 0.00076, saving model to /content/drive/MyDrive/Thesis Dataset/AUD5minGRU.hdf5
# 463/463 [==============================] - 306s 661ms/step - loss: 3.9294e-04 - mae: 0.0153 - mse: 3.9294e-04 - root_mean_squared_error: 0.0198 - mape: 955.6528 - val_loss: 7.5623e-04 - val_mae: 0.0208 - val_mse: 7.5623e-04 - val_root_mean_squared_error: 0.0275 - val_mape: 5160.7012
# Epoch 4/60
# 463/463 [==============================] - ETA: 0s - loss: 2.5285e-04 - mae: 0.0124 - mse: 2.5285e-04 - root_mean_squared_error: 0.0159 - mape: 702.9344
# Epoch 4: val_mse improved from 0.00076 to 0.00072, saving model to /content/drive/MyDrive/Thesis Dataset/AUD5minGRU.hdf5
# 463/463 [==============================] - 303s 653ms/step - loss: 2.5285e-04 - mae: 0.0124 - mse: 2.5285e-04 - root_mean_squared_error: 0.0159 - mape: 702.9344 - val_loss: 7.1875e-04 - val_mae: 0.0198 - val_mse: 7.1875e-04 - val_root_mean_squared_error: 0.0268 - val_mape: 4741.9355
# Epoch 5/60
# 463/463 [==============================] - ETA: 0s - loss: 1.7225e-04 - mae: 0.0102 - mse: 1.7225e-04 - root_mean_squared_error: 0.0131 - mape: 541.5566
# Epoch 5: val_mse improved from 0.00072 to 0.00065, saving model to /content/drive/MyDrive/Thesis Dataset/AUD5minGRU.hdf5
# 463/463 [==============================] - 293s 634ms/step - loss: 1.7225e-04 - mae: 0.0102 - mse: 1.7225e-04 - root_mean_squared_error: 0.0131 - mape: 541.5566 - val_loss: 6.4981e-04 - val_mae: 0.0186 - val_mse: 6.4981e-04 - val_root_mean_squared_error: 0.0255 - val_mape: 4590.6572
# Epoch 6/60
# 463/463 [==============================] - ETA: 0s - loss: 1.4231e-04 - mae: 0.0093 - mse: 1.4231e-04 - root_mean_squared_error: 0.0119 - mape: 562.3761
# Epoch 6: val_mse did not improve from 0.00065
# 463/463 [==============================] - 278s 601ms/step - loss: 1.4231e-04 - mae: 0.0093 - mse: 1.4231e-04 - root_mean_squared_error: 0.0119 - mape: 562.3761 - val_loss: 7.0182e-04 - val_mae: 0.0196 - val_mse: 7.0182e-04 - val_root_mean_squared_error: 0.0265 - val_mape: 4374.2681
# Epoch 7/60
# 463/463 [==============================] - ETA: 0s - loss: 1.2019e-04 - mae: 0.0085 - mse: 1.2019e-04 - root_mean_squared_error: 0.0110 - mape: 554.8697
# Epoch 7: val_mse did not improve from 0.00065
# 463/463 [==============================] - 280s 604ms/step - loss: 1.2019e-04 - mae: 0.0085 - mse: 1.2019e-04 - root_mean_squared_error: 0.0110 - mape: 554.8697 - val_loss: 7.1793e-04 - val_mae: 0.0200 - val_mse: 7.1793e-04 - val_root_mean_squared_error: 0.0268 - val_mape: 4523.9585
# Epoch 8/60
# 463/463 [==============================] - ETA: 0s - loss: 1.0591e-04 - mae: 0.0080 - mse: 1.0591e-04 - root_mean_squared_error: 0.0103 - mape: 483.8219
# Epoch 8: val_mse did not improve from 0.00065
# 463/463 [==============================] - 278s 601ms/step - loss: 1.0591e-04 - mae: 0.0080 - mse: 1.0591e-04 - root_mean_squared_error: 0.0103 - mape: 483.8219 - val_loss: 6.5438e-04 - val_mae: 0.0187 - val_mse: 6.5438e-04 - val_root_mean_squared_error: 0.0256 - val_mape: 4160.4014
# Epoch 9/60
# 463/463 [==============================] - ETA: 0s - loss: 9.9122e-05 - mae: 0.0077 - mse: 9.9122e-05 - root_mean_squared_error: 0.0100 - mape: 604.0544
# 463/463 [==============================] - ETA: 0s - loss: 5.9795e-05 - mae: 0.0059 - mse: 5.9795e-05 - root_mean_squared_error: 0.0077 - mape: 478.2065
# Epoch 26: val_mse did not improve from 0.00065
# 463/463 [==============================] - 278s 601ms/step - loss: 5.9795e-05 - mae: 0.0059 - mse: 5.9795e-05 - root_mean_squared_error: 0.0077 - mape: 478.2065 - val_loss: 7.4877e-04 - val_mae: 0.0206 - val_mse: 7.4877e-04 - val_root_mean_squared_error: 0.0274 - val_mape: 4004.9497
# Epoch 27/60
# 463/463 [==============================] - ETA: 0s - loss: 5.5129e-05 - mae: 0.0057 - mse: 5.5129e-05 - root_mean_squared_error: 0.0074 - mape: 498.4034
# Epoch 27: val_mse did not improve from 0.00065
# 463/463 [==============================] - 297s 642ms/step - loss: 5.5129e-05 - mae: 0.0057 - mse: 5.5129e-05 - root_mean_squared_error: 0.0074 - mape: 498.4034 - val_loss: 7.6748e-04 - val_mae: 0.0204 - val_mse: 7.6748e-04 - val_root_mean_squared_error: 0.0277 - val_mape: 4453.4634
# Epoch 28/60
# 393/463 [========================>.....] - ETA: 43s - loss: 5.5042e-05 - mae: 0.0057 - mse: 5.5042e-05 - root_mean_squared_error: 0.0074 - mape: 559.4171

# %%
thesis.SummarizeHistory(history)

# %%
print(min(history.history['val_mae']))
print(min(history.history['val_root_mean_squared_error']))
#print(min(histroy.history['val_mape']))
r2_scr = thesis.R_Squared_Score(model, x_val, y_val)
print(r2_scr)
# Out:
# 0.018573500216007233
# 0.02549128793179989
# 687/687 [==============================] - 35s 48ms/step
# 0.9832669567598801

# %%
model.load_weights("/content/drive/MyDrive/Thesis Dataset/AUD5minGRU.hdf5")
early_stopping = EarlyStopping(monitor='val_mse', patience=15)
from keras.callbacks import LearningRateScheduler
import keras.backend as K

def scheduler(epoch):
    if epoch%2==0 and epoch!=0:
        lr = K.get_value(model.optimizer.lr)
        K.set_value(model.optimizer.lr, lr*.9)
        print("lr changed to {}".format(lr*.9))
    return K.get_value(model.optimizer.lr)
lr_decay = LearningRateScheduler(scheduler)

callbacks_list = [checkpoint, lr_decay, early_stopping]

Epochs=25
Batch_size=385
history=thesis.CreateHistory(x_train, y_train, x_val, y_val, model, callbacks_list, Epochs, Batch_size)
# Out:
# Epoch 1/25
# 463/463 [==============================] - ETA: 0s - loss: 6.8160e-04 - mae: 0.0138 - mse: 6.8160e-04 - root_mean_squared_error: 0.0261 - mape: 725.0155
# Epoch 1: val_mse did not improve from 0.00065
# 463/463 [==============================] - 283s 597ms/step - loss: 6.8160e-04 - mae: 0.0138 - mse: 6.8160e-04 - root_mean_squared_error: 0.0261 - mape: 725.0155 - val_loss: 7.2734e-04 - val_mae: 0.0202 - val_mse: 7.2734e-04 - val_root_mean_squared_error: 0.0270 - val_mape: 4789.8286 - lr: 0.0010
# Epoch 2/25
# 463/463 [==============================] - ETA: 0s - loss: 1.1758e-04 - mae: 0.0084 - mse: 1.1758e-04 - root_mean_squared_error: 0.0108 - mape: 586.1900
# Epoch 2: val_mse did not improve from 0.00065
# 463/463 [==============================] - 271s 585ms/step - loss: 1.1758e-04 - mae: 0.0084 - mse: 1.1758e-04 - root_mean_squared_error: 0.0108 - mape: 586.1900 - val_loss: 6.7959e-04 - val_mae: 0.0192 - val_mse: 6.7959e-04 - val_root_mean_squared_error: 0.0261 - val_mape: 4227.8628 - lr: 0.0010
# lr changed to 0.0009000000427477062
# Epoch 3/25
# 463/463 [==============================] - ETA: 0s - loss: 1.0011e-04 - mae: 0.0078 - mse: 1.0011e-04 - root_mean_squared_error: 0.0100 - mape: 501.1375
# Epoch 3: val_mse did not improve from 0.00065
# 463/463 [==============================] - 271s 585ms/step - loss: 1.0011e-04 - mae: 0.0078 - mse: 1.0011e-04 - root_mean_squared_error: 0.0100 - mape: 501.1375 - val_loss: 6.8699e-04 - val_mae: 0.0193 - val_mse: 6.8699e-04 - val_root_mean_squared_error: 0.0262 - val_mape: 4072.6086 - lr: 9.0000e-04
# Epoch 4/25
# 463/463 [==============================] - ETA: 0s - loss: 9.0212e-05 - mae: 0.0073 - mse: 9.0212e-05 - root_mean_squared_error: 0.0095 - mape: 462.1419
# Epoch 4: val_mse did not improve from 0.00065
# 463/463 [==============================] - 270s 583ms/step - loss: 9.0212e-05 - mae: 0.0073 - mse: 9.0212e-05 - root_mean_squared_error: 0.0095 - mape: 462.1419 - val_loss: 6.5128e-04 - val_mae: 0.0186 - val_mse: 6.5128e-04 - val_root_mean_squared_error: 0.0255 - val_mape: 4239.0156 - lr: 9.0000e-04
# lr changed to 0.0008100000384729356
# Epoch 5/25
# 463/463 [==============================] - ETA: 0s - loss: 7.5016e-05 - mae: 0.0067 - mse: 7.5016e-05 - root_mean_squared_error: 0.0087 - mape: 565.3627
# Epoch 5: val_mse did not improve from 0.00065
# 463/463 [==============================] - 266s 575ms/step - loss: 7.5016e-05 - mae: 0.0067 - mse: 7.5016e-05 - root_mean_squared_error: 0.0087 - mape: 565.3627 - val_loss: 6.5494e-04 - val_mae: 0.0187 - val_mse: 6.5494e-04 - val_root_mean_squared_error: 0.0256 - val_mape: 4129.0562 - lr: 8.1000e-04
# Epoch 6/25
# 463/463 [==============================] - ETA: 0s - loss: 7.8138e-05 - mae: 0.0068 - mse: 7.8138e-05 - root_mean_squared_error: 0.0088 - mape: 522.5806
# Epoch 6: val_mse did not improve from 0.00065
# 463/463 [==============================] - 269s 581ms/step - loss: 7.8138e-05 - mae: 0.0068 - mse: 7.8138e-05 - root_mean_squared_error: 0.0088 - mape: 522.5806 - val_loss: 6.5516e-04 - val_mae: 0.0186 - val_mse: 6.5516e-04 - val_root_mean_squared_error: 0.0256 - val_mape: 3968.6721 - lr: 8.1000e-04
# lr changed to 0.0007290000503417104
# Epoch 7/25
# 463/463 [==============================] - ETA: 0s - loss: 6.1907e-05 - mae: 0.0060 - mse: 6.1907e-05 - root_mean_squared_error: 0.0079 - mape: 552.2210
# Epoch 7: val_mse did not improve from 0.00065
# Epoch 18/25
# 463/463 [==============================] - ETA: 0s - loss: 4.2336e-05 - mae: 0.0049 - mse: 4.2336e-05 - root_mean_squared_error: 0.0065 - mape: 477.0404
# Epoch 18: val_mse did not improve from 0.00065
# 463/463 [==============================] - 276s 596ms/step - loss: 4.2336e-05 - mae: 0.0049 - mse: 4.2336e-05 - root_mean_squared_error: 0.0065 - mape: 477.0404 - val_loss: 7.0936e-04 - val_mae: 0.0199 - val_mse: 7.0936e-04 - val_root_mean_squared_error: 0.0266 - val_mape: 3936.2075 - lr: 4.3047e-04
# lr changed to 0.00038742052274756136
# Epoch 19/25
# 463/463 [==============================] - ETA: 0s - loss: 3.9680e-05 - mae: 0.0047 - mse: 3.9680e-05 - root_mean_squared_error: 0.0063 - mape: 398.0045
# Epoch 19: val_mse did not improve from 0.00065
# 463/463 [==============================] - 273s 589ms/step - loss: 3.9680e-05 - mae: 0.0047 - mse: 3.9680e-05 - root_mean_squared_error: 0.0063 - mape: 398.0045 - val_loss: 6.7903e-04 - val_mae: 0.0191 - val_mse: 6.7903e-04 - val_root_mean_squared_error: 0.0261 - val_mape: 4115.2109 - lr: 3.8742e-04

# %%
thesis.SummarizeHistory(history)

# %%
print(min(history.history['val_mae']))
print(min(history.history['val_root_mean_squared_error']))
#print(min(histroy.history['val_mape']))
r2_scr = thesis.R_Squared_Score(model, x_val, y_val)
print(r2_scr)
# Out:
# 0.018606605008244514
# 0.025520144030451775
# 687/687 [==============================] - 39s 55ms/step
# 0.984888492314613

# %%
model.load_weights("/content/drive/MyDrive/Thesis Dataset/AUD5minGRU.hdf5")
val_predictions=thesis.CreatPrediction(model,x_val, y_val)
# Out:
# 687/687 [==============================] - 25s 36ms/step

# %%
val_predictions['diff'] = val_predictions['predicted'] - val_predictions['actual']
plt.figure(figsize=(10,10))
sns.distplot(val_predictions['diff']);
plt.title('Distribution of differences between actual and prediction for validation')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
predictions=thesis.CreatPrediction(model,x_test, y_test)
# Out:
# 704/704 [==============================] - 31s 44ms/step

# %%
predictions['diff'] = predictions['predicted'] - predictions['actual']
plt.figure(figsize=(10,10))
sns.distplot(predictions['diff']);
plt.title('Distribution of differences between actual and prediction')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print("MSE : ", mean_squared_error(predictions['predicted'].values, predictions['actual'].values))
print("MAE : ", mean_absolute_error(predictions['predicted'].values, predictions['actual'].values))
from math import sqrt

print('RMSE  :', sqrt(mean_squared_error(predictions['predicted'].values, predictions['actual'].values)))

test_r2_scr = thesis.R_Squared_Score(model, x_test, y_test)
print('R2_Score  :',test_r2_scr)


predictions['diff'].describe()
# Out:
# MSE :  0.0006853592666186972
# MAE :  0.019209862501653654
# RMSE  : 0.026179367192861965
# 704/704 [==============================] - 25s 35ms/step
# R2_Score  : 0.9887803641579187
# count    22513.000000
# mean        -0.007613
# std          0.025049
# min         -0.219073
# 25%         -0.020866
# 50%         -0.008131
# 75%          0.005585
# max          0.139265
# Name: diff, dtype: float64
